# %% [markdown]
# # Investigation of performance of net mechanism on a four-dimensional toy data set

# %%
import second_moment_experiments_main as experiment
import pickle
import matplotlib
import matplotlib.pyplot as plt
plt.rc('text', usetex = True)
plt.rc('font', family = 'serif')
matplotlib.rc('xtick', labelsize = 14) 
matplotlib.rc('ytick', labelsize = 14) 
from exputils import extract_data, initialise_netmech_containers, initialise_adassp_reg_containers, \
initialise_netmech_reg_containers, get_expected_statistics, get_optimal_utilities_statistics
from baselines import Regression, DPRegression
import numpy as np
# %matplotlib tk

# %%
# Load data 
exp_name = 'exp_vary_private_data_extended_features_3_dim_6'
with open ('D:/Thesis/Experiments/exp_vary_private_data_extended_features_3_dim_6/' + exp_name, "rb") as container:
    results = pickle.load(container)

# %% [markdown]
# ## Assess the performance of the netmechanism for sparse lattices for a wide range of datasets

# %% [markdown]
# $\textbf{Setup}$: Draw $25$ samples with the net mechanism set up with $k_f =3, k_t \in \{5,...,8\}$ for $100$ different data sets.  Compare the expected average RMSE across the $100$ datasets with the results obtained originally for the seed = 23 case. Then compute the expected average RMSE across the $100$ datasets for the ADASSP algorithm and compare the two.

# %% [markdown]
# ### Parameter setup

# %%
# Default parameters list
dimensionality = 6
num_records = 300
test_frac = 0.8
batch_size = 150
directory = '/home/alexcoca/Thesis/Experiments/exp_vary_private_data_extended_features_3_dim_6/'
parallel = True
save_data = False
partition_method = 'fast_2'
workers = -1
num_samples = 25
sample_parallel = True
load_data = False
num_points_features = 3

# %%
# Experiment specific
num_points_min = dimensionality
min_seed = 0
num_points_max = 8
num_points_targets_vec = range(num_points_min, num_points_max + 1)
num_datasets = 100
epsilon_vec = [0.1, 0.3, 0.5, 0.7, 0.9]

# %% [markdown]
# ### Run the experiments

# %%
# Initialise results data containers
results = {key_outer: {key_inner : [] for key_inner in epsilon_vec}  for key_outer in range(num_datasets)}

# %%
# Collect results
for dataset in range(min_seed, num_datasets):
    print ("Dataset number", dataset)
    for epsilon in epsilon_vec:
        for num_points_targets in num_points_targets_vec:
            results[dataset][epsilon].append(experiment.second_order_moment_experiment(dimensionality = dimensionality, num_records = num_records, \
                                                                                       test_frac = test_frac, batch_size = batch_size,directory = directory, \
                                                                                       parallel = parallel, save_data = save_data,\
                                                                                       partition_method = partition_method, workers = workers, \
                                                                                       num_samples = num_samples, sample_parallel = sample_parallel,\
                                                                                       load_data = load_data, num_points_targets = num_points_targets,\
                                                                                       num_points_features = num_points_features, epsilon = epsilon, \
                                                                                       seed = dataset))
# Out:
# Dataset number 1
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 25.64779081083287
# Max scaled utility is -0.6775716421083184
# Generation time 2.1980583667755127
# Sampling time 0.0009982585906982422
# Overall max utility -0.4517144280722123
# Elapsed time with 5 workers is 2.2020483016967773
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 52.57236499807124
# Max scaled utility is -0.13240388343487125
# Generation time 2.0974392890930176
# Sampling time 0.0
# Overall max utility -0.0882692556232475
# Elapsed time with 5 workers is 2.0974392890930176
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 859.1441625473423
# Max scaled utility is -0.11507164210831847
# Generation time 2.257277727127075
# Sampling time 0.001997232437133789
# Overall max utility -0.0767144280722123
# Elapsed time with 5 workers is 2.261423110961914
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 2376.8062217425822
# Max scaled utility is -0.0257372167682047
# Generation time 2.2242188453674316
# Sampling time 0.0
# Overall max utility -0.01715814451213647
# Elapsed time with 5 workers is 2.2242188453674316
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 9941.105933177894
# Max scaled utility is -0.04907055010153792
# Generation time 2.204148530960083
# Sampling time 0.0050678253173828125
# Overall max utility -0.03271370006769195
# Elapsed time with 5 workers is 2.2102136611938477
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 18004.74132957321
# Max scaled utility is -0.041816112993722385
# Generation time 2.1761512756347656
# Sampling time 0.0070912837982177734
# Overall max utility -0.02787740866248159
# Elapsed time with 5 workers is 2.1832425594329834
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 50801.83295023429
# Max scaled utility is -0.02555335789168154
# Generation time 2.325751543045044
# Sampling time 0.031243324279785156
# Overall max utility -0.017035571927787693
# Elapsed time with 5 workers is 2.3726158142089844
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 98978.36844132139
# Max scaled utility is -0.03247349990955383
# Generation time 2.3102948665618896
# Sampling time 0.06248617172241211
# Overall max utility -0.021648999939702554
# Elapsed time with 5 workers is 2.3904871940612793
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 211506.4092160839
# Max scaled utility is -0.015304978887318061
# Generation time 2.8939993381500244
# Sampling time 0.145768404006958
# Overall max utility -0.010203319258212041
# Elapsed time with 5 workers is 3.042759656906128
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 314937.3834713337
# Max scaled utility is -0.014144115537604772
# Generation time 2.975675344467163
# Sampling time 0.20307683944702148
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 3.1852240562438965
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 7
# Number of batches is  7
# Starting parallel pool
# Partition function is 593494.763060956
# Max scaled utility is -0.027522551129061858
# Generation time 3.124589443206787
# Sampling time 0.397141695022583
# Overall max utility -0.01834836741937457
# Elapsed time with 5 workers is 3.52173113822937
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 862557.0455904595
# Max scaled utility is -0.012483103397306466
# Generation time 3.1879971027374268
# Sampling time 0.56522536277771
# Overall max utility -0.008322068931537644
# Elapsed time with 5 workers is 3.7532224655151367
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 12
# Number of batches is  12
# Starting parallel pool
# Partition function is 1407889.7995515768
# Max scaled utility is -0.01469502111268196
# Generation time 3.3322768211364746
# Sampling time 0.765343189239502
# Overall max utility -0.009796680741787973
# Elapsed time with 5 workers is 4.097620010375977
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 15
# Number of batches is  15
# Starting parallel pool
# Partition function is 2158225.826237515
# Max scaled utility is -0.014144115537604772
# Generation time 3.7576589584350586
# Sampling time 1.3364243507385254
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 5.097076892852783
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 20
# Number of batches is  20
# Starting parallel pool
# Partition function is 3190984.1527976515
# Max scaled utility is -0.01383460789168154
# Generation time 3.732207775115967
# Sampling time 1.4141762256622314
# Overall max utility -0.009223071927787693
# Elapsed time with 5 workers is 5.146384000778198
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 24
# Number of batches is  24
# Starting parallel pool
# Partition function is 4372738.790927282
# Max scaled utility is -0.01580693622596556
# Generation time 4.0393288135528564
# Sampling time 1.8644077777862549
# Overall max utility -0.01053795748397704
# Elapsed time with 5 workers is 5.903736591339111
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 32
# Number of batches is  32
# Starting parallel pool
# Partition function is 6581743.695588355
# Max scaled utility is -0.00543576185342271
# Generation time 4.570883274078369
# Sampling time 2.4384090900421143
# Overall max utility -0.00362384123561514
# Elapsed time with 5 workers is 7.009292364120483
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 38
# Number of batches is  38
# Starting parallel pool
# Partition function is 8824492.932505503
# Max scaled utility is -0.010539896458942336
# Generation time 5.341214179992676
# Sampling time 2.8858718872070312
# Overall max utility -0.00702659763929489
# Elapsed time with 5 workers is 8.227086067199707
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 11.546540893096122
# Max scaled utility is -1.3551432842166369
# Generation time 2.2364084720611572
# Sampling time 0.0009989738464355469
# Overall max utility -0.4517144280722123
# Elapsed time with 5 workers is 2.2403995990753174
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 38.847910710656336
# Max scaled utility is -0.2648077668697425
# Generation time 2.171748638153076
# Sampling time 0.0
# Overall max utility -0.0882692556232475
# Elapsed time with 5 workers is 2.171748638153076
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 508.37631157170347
# Max scaled utility is -0.23014328421663693
# Generation time 2.2433509826660156
# Sampling time 0.0010859966278076172
# Overall max utility -0.0767144280722123
# Elapsed time with 5 workers is 2.2444369792938232
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 1605.3195208506495
# Max scaled utility is -0.0514744335364094
# Generation time 2.188817024230957
# Sampling time 0.0019953250885009766
# Overall max utility -0.01715814451213647
# Elapsed time with 5 workers is 2.193804979324341
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 6112.5900730539515
# Max scaled utility is -0.09814110020307584
# Generation time 2.194713830947876
# Sampling time 0.015623807907104492
# Overall max utility -0.03271370006769195
# Elapsed time with 5 workers is 2.2103376388549805
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 12004.217502211675
# Max scaled utility is -0.08363222598744477
# Generation time 2.1949100494384766
# Sampling time 0.0020537376403808594
# Overall max utility -0.02787740866248159
# Elapsed time with 5 workers is 2.1969637870788574
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 31947.26314663675
# Max scaled utility is -0.05110671578336308
# Generation time 2.3085198402404785
# Sampling time 0.031243324279785156
# Overall max utility -0.017035571927787693
# Elapsed time with 5 workers is 2.3553848266601562
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 63691.027509977386
# Max scaled utility is -0.06494699981910766
# Generation time 2.3673605918884277
# Sampling time 0.06972622871398926
# Overall max utility -0.021648999939702554
# Elapsed time with 5 workers is 2.437086820602417
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 131484.18410667387
# Max scaled utility is -0.030609957774636123
# Generation time 2.846468687057495
# Sampling time 0.14914321899414062
# Overall max utility -0.010203319258212041
# Elapsed time with 5 workers is 2.9956119060516357
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 203621.56627527322
# Max scaled utility is -0.028288231075209544
# Generation time 2.86161470413208
# Sampling time 0.2203962802886963
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 3.0850024223327637
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 7
# Number of batches is  7
# Starting parallel pool
# Partition function is 373257.3284896693
# Max scaled utility is -0.055045102258123715
# Generation time 3.0836269855499268
# Sampling time 0.39278531074523926
# Overall max utility -0.01834836741937457
# Elapsed time with 5 workers is 3.476412296295166
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 556784.6217814717
# Max scaled utility is -0.024966206794612932
# Generation time 3.3372721672058105
# Sampling time 0.6104192733764648
# Overall max utility -0.008322068931537644
# Elapsed time with 5 workers is 3.963552474975586
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 12
# Number of batches is  12
# Starting parallel pool
# Partition function is 894651.1200702077
# Max scaled utility is -0.02939004222536392
# Generation time 3.515958547592163
# Sampling time 1.0093674659729004
# Overall max utility -0.009796680741787973
# Elapsed time with 5 workers is 4.528317928314209
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 15
# Number of batches is  15
# Starting parallel pool
# Partition function is 1374914.2218462962
# Max scaled utility is -0.028288231075209544
# Generation time 3.5211446285247803
# Sampling time 1.2080061435699463
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 4.729150772094727
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 20
# Number of batches is  20
# Starting parallel pool
# Partition function is 2025706.6269392218
# Max scaled utility is -0.02766921578336308
# Generation time 3.5854692459106445
# Sampling time 1.5297179222106934
# Overall max utility -0.009223071927787693
# Elapsed time with 5 workers is 5.118178844451904
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 24
# Number of batches is  24
# Starting parallel pool
# Partition function is 2803724.1850338127
# Max scaled utility is -0.03161387245193112
# Generation time 3.957923173904419
# Sampling time 1.9315955638885498
# Overall max utility -0.01053795748397704
# Elapsed time with 5 workers is 5.890632390975952
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 32
# Number of batches is  32
# Starting parallel pool
# Partition function is 4156544.464292308
# Max scaled utility is -0.01087152370684542
# Generation time 4.620964288711548
# Sampling time 2.2491233348846436
# Overall max utility -0.00362384123561514
# Elapsed time with 5 workers is 6.8730788230896
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 38
# Number of batches is  38
# Starting parallel pool
# Partition function is 5629260.687850565
# Max scaled utility is -0.02107979291788467
# Generation time 5.045262336730957
# Sampling time 2.3912813663482666
# Overall max utility -0.00702659763929489
# Elapsed time with 5 workers is 7.436543703079224
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 5.352531937653833
# Max scaled utility is -2.0327149263249553
# Generation time 2.223330020904541
# Sampling time 0.0
# Overall max utility -0.4517144280722123
# Elapsed time with 5 workers is 2.223330020904541
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 29.04041269502081
# Max scaled utility is -0.39721165030461375
# Generation time 2.17515230178833
# Sampling time 0.015592813491821289
# Overall max utility -0.0882692556232475
# Elapsed time with 5 workers is 2.1907451152801514
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 320.28643799962754
# Max scaled utility is -0.3452149263249554
# Generation time 2.1613376140594482
# Sampling time 0.0
# Overall max utility -0.0767144280722123
# Elapsed time with 5 workers is 2.1613376140594482
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 1107.807101795085
# Max scaled utility is -0.0772116503046141
# Generation time 2.1819655895233154
# Sampling time 0.0
# Overall max utility -0.01715814451213647
# Elapsed time with 5 workers is 2.1819655895233154
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 3935.603500255266
# Max scaled utility is -0.14721165030461375
# Generation time 2.109865665435791
# Sampling time 0.006981372833251953
# Overall max utility -0.03271370006769195
# Elapsed time with 5 workers is 2.242579936981201
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 8220.74791393883
# Max scaled utility is -0.12544833898116714
# Generation time 2.163125991821289
# Sampling time 0.0
# Overall max utility -0.027877408662481586
# Elapsed time with 5 workers is 2.178748846054077
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 20943.473570645023
# Max scaled utility is -0.07666007367504463
# Generation time 2.381578207015991
# Sampling time 0.031244516372680664
# Overall max utility -0.017035571927787693
# Elapsed time with 5 workers is 2.412822723388672
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 42368.60518851022
# Max scaled utility is -0.09742049972866149
# Generation time 2.4129550457000732
# Sampling time 0.06905531883239746
# Overall max utility -0.021648999939702554
# Elapsed time with 5 workers is 2.4820103645324707
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 85262.68272893099
# Max scaled utility is -0.04591493666195418
# Generation time 2.8006813526153564
# Sampling time 0.14943456649780273
# Overall max utility -0.010203319258212041
# Elapsed time with 5 workers is 2.9531102180480957
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 136245.81053170183
# Max scaled utility is -0.042432346612814316
# Generation time 2.8893508911132812
# Sampling time 0.18709492683410645
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 3.0764458179473877
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 7
# Number of batches is  7
# Starting parallel pool
# Partition function is 244560.95001599737
# Max scaled utility is -0.08256765338718557
# Generation time 3.0878095626831055
# Sampling time 0.39816784858703613
# Overall max utility -0.01834836741937457
# Elapsed time with 5 workers is 3.4859774112701416
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 372321.68481363606
# Max scaled utility is -0.0374493101919194
# Generation time 3.149592638015747
# Sampling time 0.5650207996368408
# Overall max utility -0.008322068931537644
# Elapsed time with 5 workers is 3.714613437652588
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 12
# Number of batches is  12
# Starting parallel pool
# Partition function is 591690.6921320682
# Max scaled utility is -0.04408506333804588
# Generation time 3.419816255569458
# Sampling time 0.7334654331207275
# Overall max utility -0.009796680741787973
# Elapsed time with 5 workers is 4.1532816886901855
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 15
# Number of batches is  15
# Starting parallel pool
# Partition function is 909774.2502829323
# Max scaled utility is -0.042432346612814316
# Generation time 3.3667359352111816
# Sampling time 1.130615234375
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 4.497351169586182
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 20
# Number of batches is  20
# Starting parallel pool
# Partition function is 1338180.510033839
# Max scaled utility is -0.04150382367504462
# Generation time 3.6877200603485107
# Sampling time 1.6600604057312012
# Overall max utility -0.009223071927787693
# Elapsed time with 5 workers is 5.347780466079712
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 24
# Number of batches is  24
# Starting parallel pool
# Partition function is 1866813.5370196092
# Max scaled utility is -0.04742080867789668
# Generation time 4.2517101764678955
# Sampling time 2.2415990829467773
# Overall max utility -0.01053795748397704
# Elapsed time with 5 workers is 6.493309259414673
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 32
# Number of batches is  32
# Starting parallel pool
# Partition function is 2734873.6339593916
# Max scaled utility is -0.01630728556026813
# Generation time 4.507647275924683
# Sampling time 2.310283660888672
# Overall max utility -0.0036238412356151403
# Elapsed time with 5 workers is 6.8179309368133545
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 38
# Number of batches is  38
# Starting parallel pool
# Partition function is 3731320.167173183
# Max scaled utility is -0.03161968937682701
# Generation time 5.0387489795684814
# Sampling time 2.613025665283203
# Overall max utility -0.00702659763929489
# Elapsed time with 5 workers is 7.651774644851685
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 2.5208443619710765
# Max scaled utility is -2.7102865684332738
# Generation time 2.1722495555877686
# Sampling time 0.0
# Overall max utility -0.4517144280722123
# Elapsed time with 5 workers is 2.1722495555877686
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 21.95188202878269
# Max scaled utility is -0.529615533739485
# Generation time 2.123293876647949
# Sampling time 0.0
# Overall max utility -0.0882692556232475
# Elapsed time with 5 workers is 2.138916015625
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 212.62176395190977
# Max scaled utility is -0.46028656843327387
# Generation time 2.1884713172912598
# Sampling time 0.0019943714141845703
# Overall max utility -0.0767144280722123
# Elapsed time with 5 workers is 2.192460536956787
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 780.1586151412106
# Max scaled utility is -0.1029488670728188
# Generation time 2.084541082382202
# Sampling time 0.0
# Overall max utility -0.01715814451213647
# Elapsed time with 5 workers is 2.100162982940674
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 2636.4025904231066
# Max scaled utility is -0.19628220040615169
# Generation time 2.1895134449005127
# Sampling time 0.006068706512451172
# Overall max utility -0.03271370006769195
# Elapsed time with 5 workers is 2.195582151412964
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 5774.920880315849
# Max scaled utility is -0.16726445197488954
# Generation time 2.1715338230133057
# Sampling time 0.016292333602905273
# Overall max utility -0.02787740866248159
# Elapsed time with 5 workers is 2.1908206939697266
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 14245.754785599216
# Max scaled utility is -0.10221343156672616
# Generation time 2.429445743560791
# Sampling time 0.031242847442626953
# Overall max utility -0.017035571927787693
# Elapsed time with 5 workers is 2.4763097763061523
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 29080.129101839815
# Max scaled utility is -0.12989399963821532
# Generation time 2.3490262031555176
# Sampling time 0.06562614440917969
# Overall max utility -0.021648999939702554
# Elapsed time with 5 workers is 2.417642116546631
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 57448.21927761279
# Max scaled utility is -0.061219915549272245
# Generation time 2.8408122062683105
# Sampling time 0.14896059036254883
# Overall max utility -0.010203319258212041
# Elapsed time with 5 workers is 2.9927659034729004
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 94119.62821263203
# Max scaled utility is -0.05657646215041909
# Generation time 2.861788272857666
# Sampling time 0.22188854217529297
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 3.086669921875
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 7
# Number of batches is  7
# Starting parallel pool
# Partition function is 166301.21683803643
# Max scaled utility is -0.11009020451624743
# Generation time 3.0360934734344482
# Sampling time 0.3999907970428467
# Overall max utility -0.01834836741937457
# Elapsed time with 5 workers is 3.436084270477295
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 257231.37367944568
# Max scaled utility is -0.049932413589225864
# Generation time 3.3165721893310547
# Sampling time 0.5820953845977783
# Overall max utility -0.008322068931537644
# Elapsed time with 5 workers is 3.898667573928833
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 12
# Number of batches is  12
# Starting parallel pool
# Partition function is 405721.72826462076
# Max scaled utility is -0.05878008445072784
# Generation time 3.2271714210510254
# Sampling time 0.7878620624542236
# Overall max utility -0.009796680741787973
# Elapsed time with 5 workers is 4.015033483505249
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 15
# Number of batches is  15
# Starting parallel pool
# Partition function is 623395.2066191602
# Max scaled utility is -0.05657646215041909
# Generation time 3.3900773525238037
# Sampling time 1.2024445533752441
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 4.592521905899048
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 20
# Number of batches is  20
# Starting parallel pool
# Partition function is 916511.6006988154
# Max scaled utility is -0.05533843156672616
# Generation time 3.6297857761383057
# Sampling time 1.6291017532348633
# Overall max utility -0.009223071927787693
# Elapsed time with 5 workers is 5.258887529373169
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 24
# Number of batches is  24
# Starting parallel pool
# Partition function is 1286653.5639669844
# Max scaled utility is -0.06322774490386224
# Generation time 4.134780645370483
# Sampling time 1.466540813446045
# Overall max utility -0.01053795748397704
# Elapsed time with 5 workers is 5.601321458816528
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 32
# Number of batches is  32
# Starting parallel pool
# Partition function is 1867651.9614536776
# Max scaled utility is -0.02174304741369084
# Generation time 4.255478858947754
# Sampling time 2.0912766456604004
# Overall max utility -0.00362384123561514
# Elapsed time with 5 workers is 6.346755504608154
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 38
# Number of batches is  38
# Starting parallel pool
# Partition function is 2561716.057183237
# Max scaled utility is -0.04215958583576934
# Generation time 4.561735391616821
# Sampling time 2.517374038696289
# Overall max utility -0.00702659763929489
# Elapsed time with 5 workers is 7.083099126815796
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 1.1974825930079678
# Max scaled utility is -3.387858210541592
# Generation time 2.173224687576294
# Sampling time 0.0
# Overall max utility -0.4517144280722123
# Elapsed time with 5 workers is 2.173224687576294
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 16.77092970599073
# Max scaled utility is -0.6620194171743563
# Generation time 2.1330032348632812
# Sampling time 0.0
# Overall max utility -0.08826925562324751
# Elapsed time with 5 workers is 2.1330032348632812
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 147.19878056036828
# Max scaled utility is -0.5753582105415923
# Generation time 2.097301483154297
# Sampling time 0.0
# Overall max utility -0.0767144280722123
# Elapsed time with 5 workers is 2.097301483154297
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 560.021157289329
# Max scaled utility is -0.1286860838410235
# Generation time 2.1886823177337646
# Sampling time 0.0029935836791992188
# Overall max utility -0.01715814451213647
# Elapsed time with 5 workers is 2.1946675777435303
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 1827.5859993846211
# Max scaled utility is -0.24535275050768962
# Generation time 2.122701406478882
# Sampling time 0.015623092651367188
# Overall max utility -0.03271370006769195
# Elapsed time with 5 workers is 2.138324499130249
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 4155.996910163284
# Max scaled utility is -0.20908056496861194
# Generation time 2.164935827255249
# Sampling time 0.02568340301513672
# Overall max utility -0.027877408662481593
# Elapsed time with 5 workers is 2.1936416625976562
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 10013.260864544221
# Max scaled utility is -0.1277667894584077
# Generation time 2.3932721614837646
# Sampling time 0.031241893768310547
# Overall max utility -0.017035571927787693
# Elapsed time with 5 workers is 2.424514055252075
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 20551.61522789781
# Max scaled utility is -0.16236749954776916
# Generation time 2.3686728477478027
# Sampling time 0.06985902786254883
# Overall max utility -0.021648999939702554
# Elapsed time with 5 workers is 2.4385318756103516
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 40071.27758714879
# Max scaled utility is -0.0765248944365903
# Generation time 2.728572130203247
# Sampling time 0.16726326942443848
# Overall max utility -0.010203319258212041
# Elapsed time with 5 workers is 2.8979177474975586
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 66963.65530729786
# Max scaled utility is -0.07072057768802387
# Generation time 2.847559690475464
# Sampling time 0.20949673652648926
# Overall max utility -0.009429410358403183
# Elapsed time with 5 workers is 3.061046838760376
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 7
# Number of batches is  7
# Starting parallel pool
# Partition function is 116944.01304709919
# Max scaled utility is -0.13761275564530928
# Generation time 3.1199464797973633
# Sampling time 0.39852285385131836
# Overall max utility -0.01834836741937457
# Elapsed time with 5 workers is 3.5184693336486816
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 183126.19350472186
# Max scaled utility is -0.06241551698653233
# Generation time 3.2584493160247803
# Sampling time 0.4950418472290039
# Overall max utility -0.008322068931537644
# Elapsed time with 5 workers is 3.7691121101379395
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 12
# Number of batches is  12
# Starting parallel pool
# Partition function is 287411.77562243125
# Max scaled utility is -0.0734751055634098
# Generation time 3.2449605464935303
# Sampling time 0.851525068283081
# Overall max utility -0.009796680741787973
# Elapsed time with 5 workers is 4.096485614776611
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 15
# Number of batches is  15
# Starting parallel pool
# Partition function is 441029.9400949786
# Max scaled utility is -0.07072057768802387
# Generation time 3.488863706588745
# Sampling time 1.194082498550415
# Overall max utility -0.009429410358403183
# Elapsed time with 5 workers is 4.685940265655518
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 20
# Number of batches is  20
# Starting parallel pool
# Partition function is 648540.3661910685
# Max scaled utility is -0.06917303945840769
# Generation time 3.7242038249969482
# Sampling time 1.3421733379364014
# Overall max utility -0.009223071927787692
# Elapsed time with 5 workers is 5.06637716293335
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 24
# Number of batches is  24
# Starting parallel pool
# Partition function is 915102.2327883613
# Max scaled utility is -0.0790346811298278
# Generation time 4.033954858779907
# Sampling time 1.8751075267791748
# Overall max utility -0.01053795748397704
# Elapsed time with 5 workers is 5.909062385559082
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 32
# Number of batches is  32
# Starting parallel pool
# Partition function is 1318967.4164393535
# Max scaled utility is -0.02717880926711355
# Generation time 4.2960474491119385
# Sampling time 2.1429667472839355
# Overall max utility -0.0036238412356151403
# Elapsed time with 5 workers is 6.439014196395874
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 38
# Number of batches is  38
# Starting parallel pool
# Partition function is 1815923.7228279868
# Max scaled utility is -0.05269948229471168
# Generation time 4.757915496826172
# Sampling time 2.8968019485473633
# Overall max utility -0.00702659763929489
# Elapsed time with 5 workers is 7.654717445373535
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 0.571631293025417
# Max scaled utility is -4.065429852649911
# Generation time 2.169790029525757
# Sampling time 0.0
# Overall max utility -0.4517144280722123
# Elapsed time with 5 workers is 2.169790029525757
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 12.942552496099788
# Max scaled utility is -0.7944233006092275
# Generation time 2.1696579456329346
# Sampling time 0.0
# Overall max utility -0.0882692556232475
# Elapsed time with 5 workers is 2.1696579456329346
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 105.31950239425976
# Max scaled utility is -0.6904298526499107
# Generation time 2.1638331413269043
# Sampling time 0.0
# Overall max utility -0.0767144280722123
# Elapsed time with 5 workers is 2.1638331413269043
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 409.2760001945424
# Max scaled utility is -0.1544233006092282
# Generation time 2.148279905319214
# Sampling time 0.0
# Overall max utility -0.01715814451213647
# Elapsed time with 5 workers is 2.148279905319214
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 1305.238435291382
# Max scaled utility is -0.2944233006092275
# Generation time 2.1780436038970947
# Sampling time 0.005106210708618164
# Overall max utility -0.03271370006769195
# Elapsed time with 5 workers is 2.183149814605713
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 3060.0500976925036
# Max scaled utility is -0.2508966779623343
# Generation time 2.1710710525512695
# Sampling time 0.015621185302734375
# Overall max utility -0.027877408662481586
# Elapsed time with 5 workers is 2.186692237854004
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 7247.154895175444
# Max scaled utility is -0.15332014735008925
# Generation time 2.380817413330078
# Sampling time 0.031242847442626953
# Overall max utility -0.017035571927787693
# Elapsed time with 5 workers is 2.4276814460754395
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 14923.325682348732
# Max scaled utility is -0.19484099945732297
# Generation time 2.3352389335632324
# Sampling time 0.08132505416870117
# Overall max utility -0.021648999939702554
# Elapsed time with 5 workers is 2.4195544719696045
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 28835.761347552405
# Max scaled utility is -0.09182987332390836
# Generation time 2.720573663711548
# Sampling time 0.15621590614318848
# Overall max utility -0.010203319258212041
# Elapsed time with 5 workers is 2.8767895698547363
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 48948.39902141596
# Max scaled utility is -0.08486469322562863
# Generation time 2.893364191055298
# Sampling time 0.22170543670654297
# Overall max utility -0.009429410358403181
# Elapsed time with 5 workers is 3.1180624961853027
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 7
# Number of batches is  7
# Starting parallel pool
# Partition function is 84755.81353252949
# Max scaled utility is -0.16513530677437113
# Generation time 3.1461758613586426
# Sampling time 0.33263087272644043
# Overall max utility -0.01834836741937457
# Elapsed time with 5 workers is 3.4956107139587402
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 133985.85556864672
# ...
# Max scaled utility is -0.1369372482472748
# Generation time 3.259695529937744
# Sampling time 0.3325836658477783
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 3.5922791957855225
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 64156.35193600964
# Max scaled utility is -0.1703827624485245
# Generation time 3.3123393058776855
# Sampling time 0.4147787094116211
# Overall max utility -0.01262094536655737
# Elapsed time with 5 workers is 3.7271180152893066
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 12
# Number of batches is  12
# Starting parallel pool
# Partition function is 100323.76456711571
# Max scaled utility is -0.20054216348704743
# Generation time 3.525026559829712
# Sampling time 0.6465640068054199
# Overall max utility -0.014854975073114625
# Elapsed time with 5 workers is 4.187212228775024
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 15
# Number of batches is  15
# Starting parallel pool
# Partition function is 153071.92876108875
# Max scaled utility is -0.1369372482472748
# Generation time 3.6661651134490967
# Sampling time 0.9612526893615723
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 4.627417802810669
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 20
# Number of batches is  20
# Starting parallel pool
# Partition function is 225590.98558268227
# Max scaled utility is -0.1369372482472748
# Generation time 3.732685089111328
# Sampling time 1.3040721416473389
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 5.039750099182129
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 24
# Number of batches is  24
# Starting parallel pool
# Partition function is 321996.49645385105
# Max scaled utility is -0.1369372482472748
# Generation time 4.210805177688599
# Sampling time 1.8934495449066162
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 6.1198766231536865
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 32
# Number of batches is  32
# Starting parallel pool
# Partition function is 458029.6657490362
# Max scaled utility is -0.11306275175272526
# Generation time 4.866541624069214
# Sampling time 1.9051604270935059
# Overall max utility -0.00837501864835002
# Elapsed time with 5 workers is 6.77170205116272
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 38
# Number of batches is  38
# Starting parallel pool
# Partition function is 634092.9417646948
# Max scaled utility is -0.12483560493832035
# Generation time 5.2805562019348145
# Sampling time 2.244352102279663
# Overall max utility -0.00924708184728299
# Elapsed time with 5 workers is 7.5249083042144775
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 0.03643681648596103
# Max scaled utility is -6.511869251454302
# Generation time 2.0454952716827393
# Sampling time 0.000997304916381836
# Overall max utility -0.43412461676362013
# Elapsed time with 5 workers is 2.0484871864318848
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 5.05538894820136
# Max scaled utility is -0.7492500029014763
# Generation time 2.0906989574432373
# Sampling time 0.0009965896606445312
# Overall max utility -0.04995000019343175
# Elapsed time with 5 workers is 2.0946879386901855
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 39.1816601820058
# Max scaled utility is -0.9456170966997932
# Generation time 1.9940123558044434
# Sampling time 0.0
# Overall max utility -0.06304113977998621
# Elapsed time with 5 workers is 1.9940123558044434
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 149.69883208474508
# Max scaled utility is -0.3881307485456972
# Generation time 2.095808744430542
# Sampling time 0.0
# Overall max utility -0.025875383236379813
# Elapsed time with 5 workers is 2.095808744430542
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 463.3579157236405
# Max scaled utility is -0.15479741521236529
# Generation time 2.092111587524414
# Sampling time 0.015621185302734375
# Overall max utility -0.010319827680824352
# Elapsed time with 5 workers is 2.1077327728271484
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 1179.7525521593511
# Max scaled utility is -0.5849951481981648
# Generation time 2.034590721130371
# Sampling time 0.015621423721313477
# Overall max utility -0.03899967654654432
# Elapsed time with 5 workers is 2.0502121448516846
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 2734.469937576955
# Max scaled utility is -0.15215249805252756
# Generation time 2.194711685180664
# Sampling time 0.04043245315551758
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 2.23714017868042
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 5564.741483966951
# Max scaled utility is -0.15215249805252756
# Generation time 2.2708606719970703
# Sampling time 0.06970906257629395
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 2.3405697345733643
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 10620.221394323864
# Max scaled utility is -0.28258333623481036
# Generation time 2.5321342945098877
# Sampling time 0.14934134483337402
# Overall max utility -0.01883888908232069
# Elapsed time with 5 workers is 2.6814756393432617
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool
# Partition function is 18586.2531073623
# Max scaled utility is -0.1982858155736529
# Generation time 2.7594151496887207
# Sampling time 0.19355344772338867
# Overall max utility -0.01321905437157686
# Elapsed time with 5 workers is 2.9529685974121094
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 7
# Number of batches is  7
# Starting parallel pool
# Partition function is 31755.734518837577
# Max scaled utility is -0.15215249805252756
# Generation time 2.881901502609253
# Sampling time 0.2713479995727539
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 3.153249502182007
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 8
# Number of batches is  8
# Starting parallel pool
# Partition function is 51011.13528992384
# Max scaled utility is -0.18931418049836055
# Generation time 2.991689682006836
# Sampling time 0.38607192039489746
# Overall max utility -0.01262094536655737
# Elapsed time with 5 workers is 3.3777616024017334
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 12
# Number of batches is  12
# Starting parallel pool
# Partition function is 79772.3877785248
# Max scaled utility is -0.22282462609671938
# Generation time 3.3761816024780273
# Sampling time 0.5985763072967529
# Overall max utility -0.014854975073114625
# Elapsed time with 5 workers is 3.9767532348632812
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 15
# Number of batches is  15
# Starting parallel pool
# Partition function is 121586.55174312899
# Max scaled utility is -0.15215249805252756
# Generation time 3.4092156887054443
# Sampling time 0.9217936992645264
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 4.334001779556274
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 20
# Number of batches is  20
# Starting parallel pool
# Partition function is 179293.5048117748
# Max scaled utility is -0.15215249805252756
# Generation time 3.4919629096984863
# Sampling time 1.146047830581665
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 4.638010740280151
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 24
# Number of batches is  24
# Starting parallel pool
# Partition function is 256373.00231619604
# Max scaled utility is -0.15215249805252756
# Generation time 3.983581781387329
# Sampling time 1.6309638023376465
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 5.614545583724976
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 32
# Number of batches is  32
# Starting parallel pool
# Partition function is 364068.422849865
# Max scaled utility is -0.12562527972525028
# Generation time 4.108375549316406
# Sampling time 1.700087547302246
# Overall max utility -0.00837501864835002
# Elapsed time with 5 workers is 5.808463096618652
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 38
# Number of batches is  38
# Starting parallel pool
# Partition function is 504248.956264065
# Max scaled utility is -0.13870622770924484
# Generation time 4.93139123916626
# Sampling time 2.061879873275757
# Overall max utility -0.00924708184728299
# Elapsed time with 5 workers is 7.010029315948486
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 3.897899760872656e-05
# Max scaled utility is -13.023738502908603
# Generation time 2.058767795562744
# Sampling time 0.0
# Overall max utility -0.43412461676362013
# Elapsed time with 5 workers is 2.058767795562744
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 0.9189549763203289
# Max scaled utility is -1.4985000058029525
# Generation time 2.248549699783325
# Sampling time 0.0
# Overall max utility -0.04995000019343175
# Elapsed time with 5 workers is 2.248549699783325
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 6.407424902388906
# Max scaled utility is -1.8912341933995864
# Generation time 2.099600315093994
# Sampling time 0.0010247230529785156
# Overall max utility -0.06304113977998621
# Elapsed time with 5 workers is 2.1046221256256104
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 21.4243878188712
# Max scaled utility is -0.7762614970913944
# Generation time 2.1052215099334717
# Sampling time 0.0
# Overall max utility -0.025875383236379813
# Elapsed time with 5 workers is 2.1052215099334717
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 76.74711421786824
# Max scaled utility is -0.30959483042473057
# Generation time 2.1143388748168945
# Sampling time 0.0
# Overall max utility -0.010319827680824352
# Elapsed time with 5 workers is 2.12998628616333
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 1
# Number of batches is  1
# Starting parallel pool
# Partition function is 221.50122425154356
# Max scaled utility is -1.1699902963963296
# Generation time 2.063584566116333
# Sampling time 0.010942935943603516
# Overall max utility -0.03899967654654432
# Elapsed time with 5 workers is 2.076612710952759
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 494.83143863328496
# Max scaled utility is -0.3043049961050551
# Generation time 2.169149398803711
# Sampling time 0.03847765922546387
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 2.207627058029175
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 2
# Number of batches is  2
# Starting parallel pool
# Partition function is 964.7172740211183
# Max scaled utility is -0.3043049961050551
# Generation time 2.2141482830047607
# Sampling time 0.031241655349731445
# Overall max utility -0.010143499870168503
# Elapsed time with 5 workers is 2.245389938354492
# Initialising synthetic feature space lattice
# Synthetic feature space initialised
# Initialising synthethic target space lattice
# Synthethic target space initialised
# Number of batches is 4
# Number of batches is  4
# Starting parallel pool

# %%
# Save the results for latter access
exp_name = 'exp_vary_private_data_extended_features_3_dim_6'
with open (directory + exp_name, "wb") as container:
    pickle.dump(results, container)

# %% [markdown]
# ## Analyse the data

# %%
# Experimental data containers
max_utilities, avg_samples_utility, synthetic_datasets_vec, test_set, private_data = \
    initialise_netmech_containers(epsilon_vec, multiple_datasets = True, max_dataset = num_datasets)

# %%
# Extract data from the results data structure 
for dataset_number in results.keys():
    # Quantities that are epsilon independent 
    fixed_eps = 0.1
    max_utilities[dataset_number], test_set[dataset_number],private_data[dataset_number] = extract_data(results[dataset_number][fixed_eps],\
                                                                                                    multiple_datasets = True, \
                                                                                                    max_dataset = num_datasets, \
                                                                                                    eps_dependent = False)
    # Quantities that are epsilon independent
    for epsilon in results[dataset_number].keys():
        avg_samples_utility[dataset_number][epsilon], synthetic_datasets_vec[dataset_number][epsilon] = \
           extract_data(results[dataset_number][epsilon], multiple_datasets = True, max_dataset = num_datasets, \
                          eps_dependent = True)

# %%
# Initialise containers for the regression on the synthetic data sets released with netmechanism
net_mech_reg_coefs, predictive_errs_netmech, min_predictive_errs_netmech, mean_predictive_errs_netmech,\
double_std_predictive_errs_netmech = initialise_netmech_reg_containers(epsilon_vec, multiple_datasets = True,\
                                                                        max_dataset = num_datasets)

# Initialise containers for the regression on the synthetic data sets with parameters released by ADASSP
adassp_reg_coef, predictive_err_adassp, min_predictive_err_adassp, mean_predictive_err_adassp, double_std_predictive_err_adassp\
                                   = initialise_adassp_reg_containers(epsilon_vec, multiple_datasets = True, max_dataset = num_datasets)

# %%
# Fit ADASSP to the private dataset and calculate the predictive error
for dataset_number in results.keys():
    for epsilon in results[dataset_number].keys():
        adassp_regressor = DPRegression()
        adassp_reg_coef[dataset_number][epsilon] = adassp_regressor.get_parameters(private_data[dataset_number].features, \
                                                                                   private_data[dataset_number].targets,\
                                                                                   num_samples, epsilon, seed = dataset_number)
        predictive_err_adassp[dataset_number][epsilon] = Regression().calculate_predictive_error(private_data[dataset_number].test_data, \
                                                                                                 adassp_reg_coef[dataset_number][epsilon])
        min_predictive_err_adassp[dataset_number][epsilon] = np.min(predictive_err_adassp[dataset_number][epsilon])
        mean_predictive_err_adassp[dataset_number][epsilon] = np.mean(predictive_err_adassp[dataset_number][epsilon])
        double_std_predictive_err_adassp[dataset_number][epsilon] = 2*np.std(predictive_err_adassp[dataset_number][epsilon])

# %%
# Perform regression on the datasets released with the net mechanism and calculate predictive error statistics
for dataset_number in results.keys():
    for epsilon in results[dataset_number].keys():
        for synthetic_datasets in synthetic_datasets_vec[dataset_number][epsilon]:
            netmech_regressor = Regression()
            net_mech_reg_coef = netmech_regressor.fit_data(synthetic_datasets)
            net_mech_reg_coefs[dataset_number][epsilon].append(net_mech_reg_coef)
            predictive_err_netmech = netmech_regressor.calculate_predictive_error(private_data[dataset_number].test_data, \
                                                                                  net_mech_reg_coef)
            predictive_errs_netmech[dataset_number][epsilon].append(predictive_err_netmech)
            min_predictive_errs_netmech[dataset_number][epsilon].append(np.min(predictive_err_netmech))
            mean_predictive_errs_netmech[dataset_number][epsilon].append(np.mean(predictive_err_netmech))
            double_std_predictive_errs_netmech[dataset_number][epsilon].append(2*np.std(predictive_err_netmech))
# Out:
# C:\Users\alexc\OneDrive\Documents\GitHub\Thesis\baselines.py:121: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   parameters[index] = np.linalg.lstsq(Sigma_tensor[index,:,:], correlations[index])[0]

# %%
# Calculate the desired satistics           
expected_avg_utility, min_avg_utility, max_avg_utility, expected_mean_predictive_errs_netmech, \
expected_double_std_predictive_errs_netmech, expected_mean_predictive_err_adassp, \
expected_double_std_predictive_err_adassp, expected_min_predictive_errs_netmech, \
min_min_predictive_errs_netmech, max_min_predictive_errs_netmech, expected_min_predictive_err_adassp, \
min_min_predictive_err_adassp, max_min_predictive_err_adassp = get_expected_statistics(avg_samples_utility,\
                                                                    mean_predictive_errs_netmech,\
                                                                    double_std_predictive_errs_netmech,\
                                                                    mean_predictive_err_adassp,\
                                                                    double_std_predictive_err_adassp, \
                                                                    min_predictive_errs_netmech, \
                                                                    min_predictive_err_adassp, \
                                                                    epsilon_vec)
expected_optimal_utilities, min_optimal_utilities, max_optimal_utilities = get_optimal_utilities_statistics(max_utilities)

# %% [markdown]
# ## Plot the results

# %%
xcoordinate = num_points_targets_vec
# Define the range of epsilon for which various quntities are plotted
epsilon_range = [0.1, 0.6, 5.0]

# %% [markdown]
# #### Expected average samples utility

# %%
def plot_expected_avg_utility(xcoordinate, expected_avg_samples_utility, expected_optimal_utilities, epsilon):
    plt.plot(xcoordinate, expected_avg_samples_utility, 'g--^', label = r'$E[\mu_u]$' )
    plt.plot(xcoordinate, expected_optimal_utilities, 'r*', label = r'$E[opt(u)]$')
    plt.xticks(xcoordinate)
    plt.xlabel('Target lattice denisity (points)', fontsize = 20)
    plt.ylabel(r'$\mu_u$ ($\varepsilon =' + str(epsilon) + '$)', fontsize = 20)
    plt.legend(fontsize = 15)
    plt.grid(True)

for epsilon in epsilon_range:
    plot_expected_avg_utility(xcoordinate, expected_avg_utility[epsilon],\
                            expected_optimal_utilities, epsilon)
    plt.plot(xcoordinate, avg_samples_utility[23][epsilon], 'yH', label = r'$\mu_u^{23}$')
    plt.plot(xcoordinate, max_utilities[23], 'cD', label = r'$opt(u)^{23}$')
    plt.legend(fontsize = 15)
    plt.show()

# %% [markdown]
# #### Variation of average RMSE with $\varepsilon$ for various lattice densities

# %%
# print(xcoordinate)
# print(expected_mean_predictive_errs_netmech)
print(expected_mean_predictive_err_adassp)
# Out:
# {0.1: 0.28530082817460684, 0.2: 0.2737990457317348, 0.3: 0.28120204440338553, 0.4: 0.2692092676765823, 0.5: 0.2640488710768747, 0.6: 0.2608859836431199, 0.7: 0.2582257317516238, 0.8: 0.2558231072115711, 0.9: 0.2536053826064834, 1.0: 0.25155245172284046, 2.0: 0.24609813662126204, 3.0: 0.21573140717959968, 4.0: 0.2022332573586448, 5.0: 0.19061304487096492, 6.0: 0.18066294744542544, 7.0: 0.17161368114866163, 8.0: 0.16322973286810957, 9.0: 0.15595265612468748, 10.0: 0.14939092255748643}

# %%
# Calculate variation of RMSE as a function of epsilon
expected_rmse_eps_avg_netmech = {key: [] for key in xcoordinate}
expected_rmse_eps_std_netmech = {key: [] for key in xcoordinate}
expected_rmse_eps_avg_adassp = []
expected_prmse_eps_std_adassp = []

# Extract data
for epsilon in epsilon_vec[0: len(epsilon_vec)]:
    # print ("DEBUG:", mean_predictive_errs_netmech[epsilon])
    # print ("DEBUG:", len(mean_predictive_errs_netmech[epsilon]))
    for index in xcoordinate:
        expected_rmse_eps_avg_netmech[index].append(expected_mean_predictive_errs_netmech[epsilon][index - xcoordinate[0]])
        expected_rmse_eps_std_netmech[index].append(expected_double_std_predictive_errs_netmech[epsilon][index - xcoordinate[0]])

expected_rmse_eps_avg_adassp = [expected_mean_predictive_err_adassp[epsilon] for epsilon in epsilon_vec[0: len(epsilon_vec)]] 
expected_rmse_eps_std_adassp = [expected_double_std_predictive_err_adassp[epsilon] for epsilon in epsilon_vec[0: len(epsilon_vec)]]

def plot_expected_rmse_avg_epsilon(epsilon_vec, expected_rmse_eps_avg_netmech, expected_rmse_eps_avg_adassp, lattice_density,\
                                   adassp = True):
    plt.semilogx(epsilon_vec, expected_rmse_eps_avg_netmech, '--*', label = 'Net mechansim')
    if adassp:
        plt.plot(epsilon_vec, expected_rmse_eps_avg_adassp, '--*', label = 'ADASSP')
        # plt.ylim([0, 1.5]) 
    plt.xlabel(r'$\varepsilon$', fontsize = 18)
    # plt.yticks(np.arange(0,1.5, step = 0.1))
   #  plt.xticks(epsilon_vec)
    plt.ylabel('$E[\mu_{RMSE}]$ (density = ' + str(lattice_density) +  ' points)', fontsize = 18)
    plt.legend(fontsize = 14)
    plt.grid(True)
    plt.show()

xcoordinate_range = [3, 4, 5, 12,16,17, 19, 20]    
for lattice_density in xcoordinate_range:
    # print ("DEBUG, rmse_eps_avg_netmech", rmse_eps_avg_netmech[lattice_density])
    plot_expected_rmse_avg_epsilon(epsilon_vec[0: len(epsilon_vec)], expected_rmse_eps_avg_netmech[lattice_density],\
                                   expected_rmse_eps_avg_adassp, lattice_density, adassp = True)
    
# Plot average RMSE for ADASSP for selected values of the lattice density on the same graph
plt.figure(1)

#xcoordinate_range = xcoordinate
for lattice_density in xcoordinate_range:
    plt.loglog(epsilon_vec[0: len(epsilon_vec)], expected_rmse_eps_avg_netmech[lattice_density], '--*', \
                 label = 'density = ' + str(lattice_density))
plt.plot(epsilon_vec[0: len(epsilon_vec)], expected_rmse_eps_avg_adassp,'-*', label = 'ADASSP')
plt.xlabel(r'$\varepsilon$', fontsize = 20)
plt.ylabel('$E[\mu_{RMSE}]$', fontsize = 20)
plt.xticks(epsilon_vec[0: len(epsilon_vec)])
#plt.yticks(np.arange(0,3, step = 0.25))
#plt.ylim([0, 3]) 
plt.grid(True)
plt.legend(fontsize = 14, bbox_to_anchor=(0.5, 1.01), bbox_transform = plt.gcf().transFigure, loc = 'center', ncol = 3)
plt.savefig('C:/Users/alexc/OneDrive/Documents/MPhil Proj/Thesis/Chapter5/Figs/' + 'e_mean_rmse_dim_3_features_3.eps', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# #### Variation of the RMSE standard deviation with $\varepsilon$ for different lattice densities

# %%
def plot_expected_rmse_std_epsilon(epsilon_vec, expected_rmse_eps_std_netmech, expected_rmse_eps_std_adassp, lattice_density,\
                                   adassp = True):
    plt.semilogx(epsilon_vec, expected_rmse_eps_std_netmech, '--*', label = 'Net mechansim')
    if adassp:
        plt.plot(epsilon_vec, expected_rmse_eps_std_adassp, '--*', label = 'ADASSP')
        # plt.ylim([0, 1]) 
    plt.xlabel(r'$\varepsilon$', fontsize = 18)
   # plt.yticks(np.arange(0,5, step = 1))
   # plt.ylim([0, 5])
   #  plt.xticks(epsilon_vec)
    plt.ylabel(r'$\sigma_{RMSE}$ (density = ' + str(lattice_density) +  ' points)', fontsize = 18)
    plt.legend(fontsize = 14)
    plt.grid(True)
    plt.show()
xcoordinate_range = [3, 4, 5, 12,16,17, 19, 20]  

for lattice_density in xcoordinate_range:
    # print ("DEBUG, expected_rmse_eps_std_netmech", expected_rmse_eps_std_netmech[lattice_density])
    plot_expected_rmse_std_epsilon(epsilon_vec[0: len(epsilon_vec)], expected_rmse_eps_std_netmech[lattice_density],\
                          expected_rmse_eps_std_adassp, lattice_density, adassp = True)

# Plot average RMSE for ADASSP for selected values of the lattice density on the same graph
plt.figure(1)

for lattice_density in xcoordinate_range:
    plt.semilogx(epsilon_vec[0: len(epsilon_vec)], expected_rmse_eps_std_netmech[lattice_density], '--*',\
                 label = 'density = ' + str(lattice_density))
plt.plot(epsilon_vec[0: len(epsilon_vec)], expected_rmse_eps_std_adassp,'-*', label = 'ADASSP')
plt.xlabel(r'$\varepsilon$', fontsize = 20)
plt.ylabel(r'2$\sigma_{RMSE}$', fontsize = 20)
plt.xticks(epsilon_vec[0: len(epsilon_vec)])
#plt.yticks(np.arange(0, 10, step = 1))
#plt.ylim([0, 10]) 
plt.grid(True)
plt.legend(fontsize = 14, bbox_to_anchor=(0.5, 1.01), bbox_transform = plt.gcf().transFigure, loc = 'center', ncol = 3)
plt.savefig('C:/Users/alexc/OneDrive/Documents/MPhil Proj/Thesis/Chapter5/Figs/' + 'e_std_rmse_dim_3_features_3.eps', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# #### Optimal utility

# %%
print(expected_optimal_utilities)
# Out:
# [-0.28206867 -0.26450498 -0.26450498 -0.26450498 -0.26450498 -0.26450498
#  -0.26450498 -0.26450498 -0.26450498 -0.26450498 -0.26450498 -0.26450498
#  -0.26450498 -0.26450498 -0.26450498 -0.26450498 -0.26450498 -0.26450498]

# %%
# Independent of epsilon, all the experiments return the same utility
plt.plot(xcoordinate, expected_optimal_utilities, 'r*', label = r'$E[opt(u)]$')
plt.plot(xcoordinate, max_utilities[23], 'cD', label = r'$opt(u)_{23}$')
plt.plot(xcoordinate, min_optimal_utilities, 'Xk', label =r'$\min(opt(u))$' )
plt.plot(xcoordinate, max_optimal_utilities, 'Xr', label =r'$\max(opt(u))$' )
plt.xticks(xcoordinate)
# plt.yticks(np.arange(-0.07, 0.0, step = 0.01))
plt.xlabel('Lattice density (points)', fontsize = 18)
plt.ylabel(r'$opt(u)$', fontsize = 18)
# plt.ylim([-0.07,0])
plt.grid(True)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# #### Expected minimum sample error for ADASSP vs netmechanism

# %%
def plot_expected_min_rmses(xcoordinate, expected_min_predictive_errs_netmech, expected_min_predictive_err_adassp, epsilon):
    plt.plot(xcoordinate, expected_min_predictive_errs_netmech, 'bv', label = 'Net mechanism',  )
    plt.plot(xcoordinate, [expected_min_predictive_err_adassp]*len(xcoordinate), 'k^', label = 'ADASSP')
    plt.xlabel('Lattice density (points)', fontsize = 18)
    plt.ylabel(r'E[$\min$ RMSE] ($\varepsilon =' + str(epsilon) + '$)', fontsize = 18)
    plt.xticks(xcoordinate)
    plt.legend(fontsize = 14)
    plt.grid(True)
    plt.show()
epsilon_range = epsilon_vec    
for epsilon in epsilon_range:
    plot_expected_min_rmses(xcoordinate, expected_min_predictive_errs_netmech[epsilon], expected_min_predictive_err_adassp[epsilon], \
                   epsilon)

# %% [markdown]
# ### Save data for cross-experiment comparison

# %%
data = {}
data['delta_opt_avg'] = delta_opt_avg
data['delta_opt_best'] = delta_opt_best
data['max_utilities'] = max_utilities
data['rmse_eps_avg_netmech'] = rmse_eps_avg_netmech
data['rmse_eps_avg_adassp'] = rmse_eps_avg_adassp

# %%
filename = 'exp_vary_private_data'
with open (directory + filename, 'wb') as container:
    pickle.dump(data, container)

# %% [markdown]
# # Sanity checks

# %% [markdown]
# #### Calculate the raw stats and compare with output of complicated function

# %%
helper_out = {key: [] for key in epsilon_vec}
means = {key: [] for key in epsilon_vec}
mins = {key: [] for key in epsilon_vec}
maxs = {key: [] for key in epsilon_vec}
for dataset_number in avg_samples_utility.keys():
    for epsilon in avg_samples_utility[dataset_number].keys():
        helper_out[epsilon].append(avg_samples_utility[dataset_number][epsilon])
for epsilon in helper_out.keys():
    means[epsilon] = np.mean(helper_out[epsilon], axis = 0)
    mins[epsilon] = np.min(helper_out[epsilon], axis = 0)
    maxs[epsilon] = np.max(helper_out[epsilon], axis = 0)
print (means[0.1])
print (expected_avg_utility[0.1])
for key in helper_out.keys():
    assert np.all(expected_avg_utility[key] == means[key])
    assert np.all(min_avg_utility[key] == mins[key])
    assert np.all(max_avg_utility[key] == maxs[key])

# %% [markdown]
# #### Test that the data is correct

# %%
# Check that the results obtained with the parallel code are ordered correctly
with open (directory + exp_name, "rb") as container:
    results = pickle.load(container)
    
num_points_min =  3 # For correct indexing    
    
for dataset in range(num_datasets):
        for epsilon in epsilon_vec:
            for num_points_targets in num_points_targets_vec:
                experiment_name = "s" + str(dataset) + "_eps" + str(epsilon).replace(".","") + "d" + \
                            str(dimensionality) + "nt" + str(num_points_targets) + \
                            "nf" + str(num_points_features)
                    assert experiment_name == results[dataset][epsilon][num_points_targets - num_points_min]['experiment_name']
