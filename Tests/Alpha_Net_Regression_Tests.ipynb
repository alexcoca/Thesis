# %% [markdown]
# # Alpha Net Regression Tests

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle
from itertools import product, combinations
from data_generators import ContinuousGenerator 
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Data Generation

# %% [markdown]
# ### Test basic data generation

# %%
# Create a generator object
generator = ContinuousGenerator(d = 1, n = 10, perturbation = False)
# Generate data
generator.generate_data(seed = 23)
dataset = generator.data
print(dataset)
# Out:
# [[-0.55908405 -0.01934194]
#  [-0.43612472 -0.01508807]
#  [-0.54745181 -0.01893952]
#  [ 0.30627703  0.01059589]
#  [ 0.95207529  0.03293778]
#  [-0.86743612 -0.03000962]
#  [ 0.44882873  0.01552757]
#  [-1.         -0.03459577]
#  [-0.10147993 -0.00351078]
#  [-0.21503007 -0.00743913]]

# %%
# Plot data
generator.plot_data()
plt.show()

# %%
# Check the norm is bounded
norms = np.linalg.norm(dataset[:,:-1], ord = 2, axis = 1)
assert np.any(norms>1.0) == False

# %% [markdown]
# ### Test data perturbation

# %%
# Generate noisy data
generator = ContinuousGenerator(d = 1, n = 10, perturbation = True, perturbation_mean = 0, perturbation_variance= 0.02)
# Generate data
generator.generate_data(seed = 23)
dataset = generator.data

# %%
# Plot data
generator.plot_data()
plt.show()

# %% [markdown]
# ### Test selection of test data

# %%
# Generate noisy data
generator = ContinuousGenerator(d = 1, n = 10, perturbation = True, perturbation_mean = 0, perturbation_variance= 0.01)
# Generate data
generator.generate_data(seed = 23, test_frac = 0.5)
dataset = generator.data
# Plot data
generator.plot_data()
plt.show()

# %% [markdown]
# ### 2-dimensional data generation

# %%
# Generate two dimensional data set
generator = ContinuousGenerator(d = 2, n = 50, perturbation= True, perturbation_mean = 0, perturbation_variance = 1)
generator.generate_data()
dataset = generator.data
# print(dataset)

# %%
# Plot data
# % matplotlib notebook
generator.plot_data()

# %% [markdown]
# # Experiments with generating points on a sphere

# %%
# Plot a lattice inside a sphere
from itertools import product, combinations
from data_generators import ContinuousGenerator 
from mpl_toolkits.mplot3d import Axes3D
# define axes
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_aspect("equal")

# draw cube
r = [-1, 1]
for s, e in combinations(np.array(list(product(r, r, r))), 2):
    if np.sum(np.abs(s-e)) == r[1]-r[0]:
        ax.plot3D(*zip(s, e), color="b")

# Create a sphere
r = 1.0
pi = np.pi
cos = np.cos
sin = np.sin
phi, theta = np.mgrid[0:pi:101j, 0:2 * pi:101j]

x = r*sin(phi)*cos(theta)
y = r*sin(phi)*sin(theta)
z = r*cos(phi)
ax.plot_wireframe(x,y,z,alpha=0.2)

# draw points
path = 'C:/Users/alexc/OneDrive/Documents/GitHub/Thesis/Data/plots/poster/pts_inside_sphere.pickle'
with open(path,'rb') as src_data:
    points = pickle.load(src_data)
ax.scatter(points[:,0], points[:,1], points[:,2], color="g", s=50)
plt.show()
